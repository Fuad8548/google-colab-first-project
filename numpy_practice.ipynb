# %% [markdown]
# <a href="https://colab.research.google.com/github/Fuad8548/google-colab-first-project/blob/main/numpy_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

a = np.array([
   # 0  1  2
    [1, 2, 3], # 0
    [4, 5, 6], # 1
    [7, 8, 9]  # 2
    ])

# indexing and slicing of metrices
# a[1, 0]       # 2nd row, 1st column
# a[0:2]        # 1st col to 2nd col, ignoring 3rd
# a[:, :2]      # all the rows, 1st & 2nd col
# a[:2, :2]     # 1st & 2nd rows, 1st & 2nd col
# a[:2, 2:]     # 1st & 2nd rows, last col
# a[1] = np.array([12, 13, 14])     # replaces the entire 2nd row


# Summary Statistics
# a.sum()
# a.mean(axis=0)
# a.std(axis=1)
# b = np.array([1, 2, 3])
# a + b


# pandas indexing and conditionals
# certificates_earned = pd.Series(
#     [8, 2, 5, 6],
#     index=['Tom', 'Kris', 'Ahmad', 'Beau']
# )

# print(certificates_earned[certificates_earned > 5])
# Out:
# array([[ 2,  4,  6],
#        [ 5,  7,  9],
#        [ 8, 10, 12]])
